# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('../data/kc_house_data.csv')

# %%
data.head(10)
# Out:
#            id        date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014   221900.0         3       1.00         1180
# 1  6414100192   12/9/2014   538000.0         3       2.25         2570
# 2  5631500400   2/25/2015   180000.0         2       1.00          770
# 3  2487200875   12/9/2014   604000.0         4       3.00         1960
# 4  1954400510   2/18/2015   510000.0         3       2.00         1680
# 5  7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6  1321400060   6/27/2014   257500.0         3       2.25         1715
# 7  2008000270   1/15/2015   291850.0         3       1.50         1060
# 8  2414600126   4/15/2015   229500.0         3       1.00         1780
# 9  3793500160   3/12/2015   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# ...

# %%
data.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
df = data

# %%
df.drop("id", inplace=True, axis=1)

# %%
df
# Out:
#              date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      10/13/2014  221900.0         3       1.00         1180      5650
# 1       12/9/2014  538000.0         3       2.25         2570      7242
# 2       2/25/2015  180000.0         2       1.00          770     10000
# 3       12/9/2014  604000.0         4       3.00         1960      5000
# 4       2/18/2015  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21592   5/21/2014  360000.0         3       2.50         1530      1131
# 21593   2/23/2015  400000.0         4       2.50         2310      5813
# 21594   6/23/2014  402101.0         2       0.75         1020      1350
# 21595   1/16/2015  400000.0         3       2.50         1600      2388
# 21596  10/15/2014  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
sns.scatterplot(x='sqft_living', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
sns.scatterplot(x='grade', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
sns.scatterplot(x='bedrooms', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='bedrooms', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
sns.countplot(x='waterfront', hue='bedrooms',  data=df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='count'>

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x='long', y='lat', hue='price', data=df)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x='long', y='lat', hue='price', palette='rainbow', data=df)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
df.sort_values('price', ascending=False).head(20)
# Out:
#              date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 7245   10/13/2014  7700000.0         6       8.00        12050     27600
# 3910    6/11/2014  7060000.0         5       4.50        10040     37325
# 9245    9/19/2014  6890000.0         6       7.75         9890     31374
# 4407     8/4/2014  5570000.0         5       5.75         9200     35069
# 1446    4/13/2015  5350000.0         5       5.00         8000     23985
# 1313    4/13/2015  5300000.0         6       6.00         7390     24829
# 1162   10/20/2014  5110000.0         5       5.25         8010     45517
# 8085    6/17/2014  4670000.0         5       6.75         9640     13068
# 2624    8/15/2014  4500000.0         5       5.50         6640     40014
# 8629    6/18/2014  4490000.0         4       3.00         6430     27517
# 12358    5/6/2015  4210000.0         5       6.00         7440     21540
# 4145   10/14/2014  4000000.0         4       5.50         7080     16573
# ...

# %%
len(df)*(0.01)
# Out:
# 215.97

# %%
non_top_1_perc = df.sort_values('price', ascending=False).iloc[216:]

# %%
non_top_1_perc
# Out:
#              date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 6329     6/2/2014  1970000.0         4       3.50         4370      8510
# 12271  10/15/2014  1960000.0         5       4.50         6200     23373
# 9166    2/13/2015  1960000.0         3       1.75         3330     12566
# 12565   4/22/2015  1960000.0         4       4.00         4430     31353
# 1150    4/21/2015  1960000.0         4       2.75         3120      7898
# ...           ...        ...       ...        ...          ...       ...
# 2139     5/8/2014    82500.0         2       1.00          520     22334
# 8267    11/5/2014    82000.0         3       1.00          860     10426
# 16184   3/24/2015    81000.0         2       1.00          730      9975
# 465     5/23/2014    80000.0         1       0.75          430      5050
# 15279    5/6/2014    78000.0         2       1.00          780     16344
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
plt.figure(figsize=(14,10))
sns.scatterplot(x='long', y='lat', hue='price', data=non_top_1_perc, alpha=1, palette='rainbow', edgecolor=None)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(14,10))
sns.scatterplot(x='long', y='lat', hue='price', data=non_top_1_perc, alpha=1, palette='viridis')
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
sns.boxplot(x='waterfront', y='price', data=df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
non_top_1_perc['date'] = pd.to_datetime(non_top_1_perc['date'])

# %%
non_top_1_perc['month'] = non_top_1_perc['date'].apply(lambda date:date.month)

# %%
non_top_1_perc['year'] = non_top_1_perc["date"].apply(lambda date:date.year)

# %%
non_top_1_perc
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 6329  2014-06-02  1970000.0         4       3.50         4370      8510
# 12271 2014-10-15  1960000.0         5       4.50         6200     23373
# 9166  2015-02-13  1960000.0         3       1.75         3330     12566
# 12565 2015-04-22  1960000.0         4       4.00         4430     31353
# 1150  2015-04-21  1960000.0         4       2.75         3120      7898
# ...          ...        ...       ...        ...          ...       ...
# 2139  2014-05-08    82500.0         2       1.00          520     22334
# 8267  2014-11-05    82000.0         3       1.00          860     10426
# 16184 2015-03-24    81000.0         2       1.00          730      9975
# 465   2014-05-23    80000.0         1       0.75          430      5050
# 15279 2014-05-06    78000.0         2       1.00          780     16344
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# ...

# %%
sns.scatterplot(x='price', y='year', data=non_top_1_perc)
# Out:
# <AxesSubplot:xlabel='price', ylabel='year'>

# %%
plt.figure(figsize=(14,14))
sns.lineplot(x='price', y='year', data=non_top_1_perc)
# Out:
# <AxesSubplot:xlabel='price', ylabel='year'>

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x='month', y='price', data=non_top_1_perc)
# Out:
# <AxesSubplot:xlabel='month', ylabel='price'>

# %%
non_top_1_perc.groupby('month').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='month'>

# %%
non_top_1_perc.groupby('year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
non_top_1_perc.head()
# Out:
#             date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 6329  2014-06-02  1970000.0         4       3.50         4370      8510
# 12271 2014-10-15  1960000.0         5       4.50         6200     23373
# 9166  2015-02-13  1960000.0         3       1.75         3330     12566
# 12565 2015-04-22  1960000.0         4       4.00         4430     31353
# 1150  2015-04-21  1960000.0         4       2.75         3120      7898
#
#        floors  waterfront  view  condition  ...  sqft_basement  yr_built  \
# 6329      2.0           0     1          3  ...            760      2003
# 12271     3.0           0     1          4  ...           1150      1988
# 9166      1.0           1     4          4  ...           1390      1960
# 12565     2.0           0     0          3  ...              0      1998
# 1150      1.0           1     4          4  ...           1560      1963
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
non_top_1_perc.drop('date', inplace=True, axis=1)

# %%
non_top_1_perc
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6329   1970000.0         4       3.50         4370      8510     2.0
# 12271  1960000.0         5       4.50         6200     23373     3.0
# 9166   1960000.0         3       1.75         3330     12566     1.0
# 12565  1960000.0         4       4.00         4430     31353     2.0
# 1150   1960000.0         4       2.75         3120      7898     1.0
# ...          ...       ...        ...          ...       ...     ...
# 2139     82500.0         2       1.00          520     22334     1.0
# 8267     82000.0         3       1.00          860     10426     1.0
# 16184    81000.0         2       1.00          730      9975     1.0
# 465      80000.0         1       0.75          430      5050     1.0
# 15279    78000.0         2       1.00          780     16344     1.0
#
#        waterfront  view  condition  grade  ...  sqft_basement  yr_built  \
# ...

# %%
non_top_1_perc.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# month            0
# year             0
# dtype: int64

# %%
plt.figure(figsize=(12,14))
sns.boxplot(x='zipcode', y='price', data=non_top_1_perc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33236/3975206213.py in <module>
#       1 plt.figure(figsize=(12,14))
# ----> 2 sns.boxplot(x='zipcode', y='price', data=non_top_1_perc)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
# ...

# %%
plt.figure(figsize=(12,14))
sns.scatterplot(x='zipcode', y='price', data=non_top_1_perc)
# Out:
# <AxesSubplot:xlabel='zipcode', ylabel='price'>

# %%
plt.figure(figsize=(14,14))
sns.lmplot(x='zipcode', y='price', data=non_top_1_perc)

# %%
non_top_1_perc.drop('zipcode', inplace=True, axis=1)

# %%
non_top_1_perc.head()
# Out:
#            price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 6329   1970000.0         4       3.50         4370      8510     2.0
# 12271  1960000.0         5       4.50         6200     23373     3.0
# 9166   1960000.0         3       1.75         3330     12566     1.0
# 12565  1960000.0         4       4.00         4430     31353     2.0
# 1150   1960000.0         4       2.75         3120      7898     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 6329            0     1          3     10        3610            760
# 12271           0     1          4     11        5050           1150
# 9166            1     4          4      8        1940           1390
# 12565           0     0          3     12        4430              0
# 1150            1     4          4      8        1560           1560
#
#        yr_built  yr_renovated      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
non_top_1_perc['yr_renovated'].value_counts()
# Out:
# 0       20499
# 2014       91
# 2013       36
# 2000       34
# 2005       34
#         ...
# 1934        1
# 1954        1
# 1948        1
# 1959        1
# 1951        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
non_top_1_perc.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'month', 'year'],
#       dtype='object')

# %%
X = non_top_1_perc.drop('price', axis=1).values

# %%
y = non_top_1_perc['price'].values

# %%
scalar = MinMaxScaler()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_train
# Out:
# array([[4.0000e+00, 1.5000e+00, 1.3500e+03, ..., 8.1130e+03, 7.0000e+00,
#         2.0140e+03],
#        [3.0000e+00, 1.0000e+00, 1.4300e+03, ..., 4.5990e+03, 1.1000e+01,
#         2.0140e+03],
#        [4.0000e+00, 1.0000e+00, 1.4400e+03, ..., 8.4660e+03, 1.2000e+01,
#         2.0140e+03],
#        ...,
#        [3.0000e+00, 2.5000e+00, 1.6100e+03, ..., 1.0017e+04, 4.0000e+00,
#         2.0150e+03],
#        [3.0000e+00, 2.2500e+00, 1.4500e+03, ..., 4.0400e+03, 2.0000e+00,
#         2.0150e+03],
#        [2.0000e+00, 2.0000e+00, 1.3400e+03, ..., 4.2730e+03, 7.0000e+00,
#         2.0140e+03]])

# %%
scalar.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scalar.transform(X_train)
X_train
# Out:
# array([[0.09375   , 0.14285714, 0.13315217, ..., 0.0085716 , 0.54545455,
#         0.        ],
#        [0.0625    , 0.07142857, 0.14402174, ..., 0.00453507, 0.90909091,
#         0.        ],
#        [0.09375   , 0.07142857, 0.14538043, ..., 0.00897709, 1.        ,
#         0.        ],
#        ...,
#        [0.0625    , 0.28571429, 0.16847826, ..., 0.01075873, 0.27272727,
#         1.        ],
#        [0.0625    , 0.25      , 0.14673913, ..., 0.00389295, 0.09090909,
#         1.        ],
#        [0.03125   , 0.21428571, 0.13179348, ..., 0.00416059, 0.54545455,
#         0.        ]])

# %%
X_test = scalar.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Activation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

# %%
'''Choosing an optimizer and loss¶
Keep in mind what kind of problem you are trying to solve:

# For a multi-class classification problem
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# For a binary classification problem
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# For a mean squared error regression problem
model.compile(optimizer='rmsprop',
              loss='mse')'''
# Out:
# "Choosing an optimizer and loss¶\nKeep in mind what kind of problem you are trying to solve:\n\n# For a multi-class classification problem\nmodel.compile(optimizer='rmsprop',\n              loss='categorical_crossentropy',\n              metrics=['accuracy'])\n\n# For a binary classification problem\nmodel.compile(optimizer='rmsprop',\n              loss='binary_crossentropy',\n              metrics=['accuracy'])\n\n# For a mean squared error regression problem\nmodel.compile(optimizer='rmsprop',\n              loss='mse')"

# %%
model.add(Dense(20, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_train, y_train, verbose=1, validation_data=(X_test,y_test),
          batch_size=128, epochs=400)
# Out:
# Epoch 1/400
# 117/117 [==============================] - 3s 4ms/step - loss: 346856456192.0000 - val_loss: 356752850944.0000
# Epoch 2/400
# 117/117 [==============================] - 0s 2ms/step - loss: 344454594560.0000 - val_loss: 348151840768.0000
# Epoch 3/400
# 117/117 [==============================] - 0s 2ms/step - loss: 311261429760.0000 - val_loss: 272505094144.0000
# Epoch 4/400
# 117/117 [==============================] - 0s 2ms/step - loss: 180844609536.0000 - val_loss: 99442860032.0000
# Epoch 5/400
# 117/117 [==============================] - 0s 2ms/step - loss: 64629612544.0000 - val_loss: 55486156800.0000
# Epoch 6/400
# 117/117 [==============================] - 0s 2ms/step - loss: 53784715264.0000 - val_loss: 54153052160.0000
# Epoch 7/400
# 117/117 [==============================] - 0s 2ms/step - loss: 52719136768.0000 - val_loss: 53005651968.0000
# Epoch 8/400
# ...

# %%
loss = model.history.history

# %%
loss
# Out:
# {'loss': [346856456192.0,
#   344454594560.0,
#   311261429760.0,
#   180844609536.0,
#   64629612544.0,
#   53784715264.0,
#   52719136768.0,
#   51617439744.0,
#   50499420160.0,
#   49362825216.0,
#   48164429824.0,
#   47026499584.0,
#   45807845376.0,
#   44569866240.0,
#   43296968704.0,
#   42045509632.0,
#   40747343872.0,
#   39430660096.0,
#   38160142336.0,
#   36893990912.0,
#   35666223104.0,
#   34476441600.0,
#   33364834304.0,
#   32348876800.0,
#   31420764160.0,
#   30595377152.0,
#   29841823744.0,
#   29189926912.0,
#   28607012864.0,
#   28112721920.0,
#   27657455616.0,
#   27261310976.0,
#   26910357504.0,
#   26607575040.0,
#   26331213824.0,
#   26063671296.0,
#   25842890752.0,
#   25622261760.0,
#   25412696064.0,
#   25235910656.0,
#   25071433728.0,
#   24902445056.0,
#   24749697024.0,
#   24647510016.0,
#   24517373952.0,
#   24418770944.0,
#   24313116672.0,
#   24233207808.0,
#   24112375808.0,
#   23994380288.0,
#   23906015232.0,
#   23819755520.0,
# ...

# %%
loss = pd.DataFrame(loss)

# %%
loss
# Out:
#              loss      val_loss
# 0    3.468565e+11  3.567529e+11
# 1    3.444546e+11  3.481518e+11
# 2    3.112614e+11  2.725051e+11
# 3    1.808446e+11  9.944286e+10
# 4    6.462961e+10  5.548616e+10
# ..            ...           ...
# 395  1.951235e+10  2.039056e+10
# 396  1.950968e+10  2.032287e+10
# 397  1.950941e+10  2.031521e+10
# 398  1.950913e+10  2.032609e+10
# 399  1.951019e+10  2.030320e+10
#
# [400 rows x 2 columns]

# %%
plt.figure(figsize=(14,14))
loss.plot(figsize=(14,14))
# Out:
# <AxesSubplot:>

# %%
y_pred = model.predict(X_test)
# Out:
# 201/201 [==============================] - 0s 993us/step

# %%
y_pred
# Out:
# array([[843955.9 ],
#        [552046.  ],
#        [458190.75],
#        ...,
#        [481023.97],
#        [457366.62],
#        [620977.3 ]], dtype=float32)

# %%
type(y_test)
# Out:
# numpy.ndarray

# %%
print(y_test.shape)
print(y_pred.shape)
# Out:
# (6415,)
# (6415, 1)

# %%
type(y_pred)
# Out:
# numpy.ndarray

# %%
sns.scatterplot(y_test, y_pred.reshape(6415,))
plt.plot(y_test, y_test, 'r')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %%
print("MSE   : %s" % mean_squared_error(y_test, y_pred))
print("RSE   : %s" % (mean_squared_error(y_test, y_pred)**0.5))
print("MAE   : %s" % mean_absolute_error(y_test, y_pred))
print("EVS   : %s" % explained_variance_score(y_test, y_pred))
# Out:
# MSE   : 20303203284.221348
# MSE   : 142489.30936818154
# MAE   : 95915.99361481878
# EVS   : 0.7535655048266799

# %%
plt.plot(y_test, y_test, 'r')

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
single_house = non_top_1_perc.iloc[0]
single_house
# Out:
# price            1.970000e+06
# bedrooms         4.000000e+00
# bathrooms        3.500000e+00
# sqft_living      4.370000e+03
# sqft_lot         8.510000e+03
# floors           2.000000e+00
# waterfront       0.000000e+00
# view             1.000000e+00
# condition        3.000000e+00
# grade            1.000000e+01
# sqft_above       3.610000e+03
# sqft_basement    7.600000e+02
# yr_built         2.003000e+03
# yr_renovated     0.000000e+00
# lat              4.758760e+01
# long            -1.222040e+02
# sqft_living15    2.960000e+03
# sqft_lot15       1.034700e+04
# month            6.000000e+00
# year             2.014000e+03
# Name: 6329, dtype: float64

# %%
single_house.shape
# Out:
# (20,)

# %%
single_house.drop('price')
# Out:
# bedrooms             4.0000
# bathrooms            3.5000
# sqft_living       4370.0000
# sqft_lot          8510.0000
# floors               2.0000
# waterfront           0.0000
# view                 1.0000
# condition            3.0000
# grade               10.0000
# sqft_above        3610.0000
# sqft_basement      760.0000
# yr_built          2003.0000
# yr_renovated         0.0000
# lat                 47.5876
# long              -122.2040
# sqft_living15     2960.0000
# sqft_lot15       10347.0000
# month                6.0000
# year              2014.0000
# Name: 6329, dtype: float64

# %%
type(single_house)
# Out:
# pandas.core.series.Series

# %%
single_house.values
# Out:
# array([ 1.97000e+06,  4.00000e+00,  3.50000e+00,  4.37000e+03,
#         8.51000e+03,  2.00000e+00,  0.00000e+00,  1.00000e+00,
#         3.00000e+00,  1.00000e+01,  3.61000e+03,  7.60000e+02,
#         2.00300e+03,  0.00000e+00,  4.75876e+01, -1.22204e+02,
#         2.96000e+03,  1.03470e+04,  6.00000e+00,  2.01400e+03])

# %%
single_house = single_house.drop('price').values.reshape(-1, 19)

# %%
single_house
# Out:
# array([[ 4.00000e+00,  3.50000e+00,  4.37000e+03,  8.51000e+03,
#          2.00000e+00,  0.00000e+00,  1.00000e+00,  3.00000e+00,
#          1.00000e+01,  3.61000e+03,  7.60000e+02,  2.00300e+03,
#          0.00000e+00,  4.75876e+01, -1.22204e+02,  2.96000e+03,
#          1.03470e+04,  6.00000e+00,  2.01400e+03]])

# %%
single_house = scalar.transform(single_house)

# %%
single_house
# Out:
# array([[0.09375   , 0.42857143, 0.54347826, 0.00686265, 0.4       ,
#         0.        , 0.25      , 0.5       , 0.7       , 0.45957447,
#         0.26666667, 0.89565217, 0.        , 0.69449807, 0.25854879,
#         0.47505101, 0.0111378 , 0.45454545, 0.        ]])

# %%
price_pred = model.predict(single_house)
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %%
price_pred
# Out:
# array([[1121803.4]], dtype=float32)

# %%
1.970000e+06
# Out:
# 1970000.0

# %%
1121803.4
# Out:
# 1121803.4
